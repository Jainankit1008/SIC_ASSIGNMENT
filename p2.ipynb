# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Lenovo\Desktop\ankit_chut\Housing_Data.csv")

# %%
df.head
# Out:
# <bound method NDFrame.head of      Unnamed: 0     price  lotsize  bedrooms  bathrms  stories driveway  \
# 0             1   42000.0     5850         3        1        2      yes
# 1             2   38500.0     4000         2        1        1      yes
# 2             3   49500.0     3060         3        1        1      yes
# 3             4   60500.0     6650         3        1        2      yes
# 4             5   61000.0     6360         2        1        1      yes
# ..          ...       ...      ...       ...      ...      ...      ...
# 541         542   91500.0     4800         3        2        4      yes
# 542         543   94000.0     6000         3        2        4      yes
# 543         544  103000.0     6000         3        2        4      yes
# 544         545  105000.0     6000         3        2        2      yes
# 545         546  105000.0     6000         3        1        2      yes
#
#     recroom fullbase gashw airco  garagepl prefarea
# ...

# %%
df["price"].mean()
# Out:
# np.float64(68121.59706959708)

# %%
pip install chart
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import chart
x=[1,1,2,2,2,3,3,3,3,3,8,5,5,3,5,8,8,9,9,2,2]
chart.histogram(x)
# Out:
# ▇
# ▇ ▇
# ▇ ▇
# ▇ ▇     ▇
# ▇ ▇     ▇
# ▇ ▇     ▇
# ▇ ▇ ▇   ▇
# ▇ ▇ ▇   ▇
# ▇ ▇ ▇   ▇
# ▇ ▇ ▇   ▇

# %%
import random
x=random.uniform(1.5,10)
print(x)
# Out:
# 2.797398305730589
