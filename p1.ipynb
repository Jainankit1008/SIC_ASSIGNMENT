# %%
import pandas as pd
import numpy as np
a1=np.array([1,2,3,4])
type(a1)
# Out:
# numpy.ndarray

# %%
a2=np.array(range(100,200))
a2[::-1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 a2=np.array(range(100,200))
#       2 a2[::-1]
#
# NameError: name 'np' is not defined

# %%
a2.reshape(25,4)
a2.resize(10,10)
a2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 a2.reshape(25,4)
#       2 a2.resize(10,10)
#       3 a2
#
# NameError: name 'a2' is not defined

# %%
a2.T
# Out:
# array([[100, 110, 120, 130, 140, 150, 160, 170, 180, 190],
#        [101, 111, 121, 131, 141, 151, 161, 171, 181, 191],
#        [102, 112, 122, 132, 142, 152, 162, 172, 182, 192],
#        [103, 113, 123, 133, 143, 153, 163, 173, 183, 193],
#        [104, 114, 124, 134, 144, 154, 164, 174, 184, 194],
#        [105, 115, 125, 135, 145, 155, 165, 175, 185, 195],
#        [106, 116, 126, 136, 146, 156, 166, 176, 186, 196],
#        [107, 117, 127, 137, 147, 157, 167, 177, 187, 197],
#        [108, 118, 128, 138, 148, 158, 168, 178, 188, 198],
#        [109, 119, 129, 139, 149, 159, 169, 179, 189, 199]])

# %%
a1*a1
# Out:
# array([ 1,  4,  9, 16])

# %%
2*a1
# Out:
# array([2, 4, 6, 8])

# %%
a5=np.array([8,5,3,2])
a5-a1*2
# Out:
# array([ 6,  1, -3, -6])

# %%
np.sin(a1)
# Out:
# array([ 0.84147098,  0.90929743,  0.14112001, -0.7568025 ])

# %%
np.sin(a2)
# Out:
# array([[-0.50636564,  0.45202579,  0.99482679,  0.62298863, -0.3216224 ,
#         -0.97053528, -0.7271425 ,  0.18478174,  0.92681851,  0.81674261],
#        [-0.04424268, -0.86455145, -0.8899956 , -0.09718191,  0.78498039,
#          0.94543533,  0.23666139, -0.68969794, -0.98195217, -0.3714041 ],
#        [ 0.58061118,  0.99881522,  0.49871315, -0.45990349, -0.99568699,
#         -0.61604046,  0.32999083,  0.97263007,  0.72103771, -0.19347339],
#        [-0.93010595, -0.81160339,  0.05308359,  0.86896576,  0.88592482,
#          0.08836869, -0.79043321, -0.94251445, -0.22805226,  0.69608013],
#        [ 0.98023966,  0.36317137, -0.58779501, -0.99834536, -0.49102159,
#          0.46774516,  0.99646917,  0.60904402, -0.33833339, -0.97464865],
#        [-0.71487643,  0.20214988,  0.93332052,  0.80640058, -0.06192034,
#         -0.87331198, -0.88178462, -0.07954854,  0.7958241 ,  0.93951973],
#        [ 0.21942526, -0.70240779, -0.97845035, -0.35491018,  0.59493278,
# ...

# %%
np.cos(a1)
# Out:
# array([ 0.54030231, -0.41614684, -0.9899925 , -0.65364362])

# %%
np.tan(a1)
# Out:
# array([ 1.55740772, -2.18503986, -0.14254654,  1.15782128])

# %%
a=np.sin(a1)/np.cos(a1)
a
# Out:
# array([ 1.55740772, -2.18503986, -0.14254654,  1.15782128])

# %%
np.log(a2)
# Out:
# array([[4.60517019, 4.61512052, 4.62497281, 4.63472899, 4.6443909 ,
#         4.65396035, 4.66343909, 4.67282883, 4.68213123, 4.69134788],
#        [4.70048037, 4.7095302 , 4.71849887, 4.72738782, 4.73619845,
#         4.74493213, 4.75359019, 4.76217393, 4.77068462, 4.77912349],
#        [4.78749174, 4.79579055, 4.80402104, 4.81218436, 4.82028157,
#         4.82831374, 4.83628191, 4.84418709, 4.85203026, 4.8598124 ],
#        [4.86753445, 4.87519732, 4.88280192, 4.89034913, 4.8978398 ,
#         4.90527478, 4.91265489, 4.91998093, 4.92725369, 4.93447393],
#        [4.94164242, 4.94875989, 4.95582706, 4.96284463, 4.9698133 ,
#         4.97673374, 4.98360662, 4.99043259, 4.99721227, 5.00394631],
#        [5.01063529, 5.01727984, 5.02388052, 5.03043792, 5.0369526 ,
#         5.04342512, 5.04985601, 5.05624581, 5.06259503, 5.0689042 ],
#        [5.07517382, 5.08140436, 5.08759634, 5.0937502 , 5.09986643,
#         5.10594547, 5.11198779, 5.11799381, 5.12396398, 5.12989871],
# ...

# %%
np.insert(a2,2,300)
# Out:
# array([100, 101, 300, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111,
#        112, 113, 114, 115, 116, 117, 118, 119, 120, 121, 122, 123, 124,
#        125, 126, 127, 128, 129, 130, 131, 132, 133, 134, 135, 136, 137,
#        138, 139, 140, 141, 142, 143, 144, 145, 146, 147, 148, 149, 150,
#        151, 152, 153, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163,
#        164, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 175, 176,
#        177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187, 188, 189,
#        190, 191, 192, 193, 194, 195, 196, 197, 198, 199])

# %%
np.acosh(a1)
# Out:
# array([0.        , 1.3169579 , 1.76274717, 2.06343707])

# %%
np.linalg.det(a2)
# Out:
# np.float64(0.0)

# %%
np.linalg.eig(a2)
# Out:
# EigResult(eigenvalues=array([ 1.50049817e+03+0.00000000e+00j, -4.16544785e-14+0.00000000e+00j,
#        -5.49817397e+00+0.00000000e+00j, -2.56408990e-14+0.00000000e+00j,
#        -2.43595632e-14+0.00000000e+00j,  7.60984121e-15+2.01466028e-14j,
#         7.60984121e-15-2.01466028e-14j,  1.26217736e-14+0.00000000e+00j,
#        -7.10533692e-16+1.80654556e-15j, -7.10533692e-16-1.80654556e-15j]), eigenvectors=array([[-0.21744297+0.j        , -0.80903983+0.j        ,
#          0.50139513+0.j        ,  0.30349354+0.j        ,
#         -0.30160459+0.j        , -0.12252341+0.11687475j,
#         -0.12252341-0.11687475j, -0.06421101+0.j        ,
#          0.05670532-0.04957169j,  0.05670532+0.04957169j],
#        [-0.238142  +0.j        ,  0.35957326+0.j        ,
#          0.39131892+0.j        , -0.21306956+0.j        ,
#          0.19821213+0.j        ,  0.06343304-0.18136514j,
#          0.06343304+0.18136514j,  0.22290772+0.j        ,
# ...

# %%
np.std(a1)
# Out:
# np.float64(1.118033988749895)

# %%
np.std(a2)
# Out:
# np.float64(28.86607004772212)

# %%
np.sum(a1)
# Out:
# np.int64(10)

# %%
import pandas as pd
s=[10,20,30,40,50]
t=[23,345,123]
sr1=pd.Series(s)
sr2=pd.Series(t)
sr3=sr1+sr2
print(sr3)
print(sr3.count())
print(sr3.sum())
# Out:
# 0     33.0
# 1    365.0
# 2    153.0
# 3      NaN
# 4      NaN
# dtype: float64
# 3
# 551.0

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4],[1,4,9,16])
plt.show()

# %%
import matplotlib.pyplot as plt
x=range(100)
y=[value**2 for value in x]
plt.plot(x,y,linewidth=5.0,color='red')
plt.show()
